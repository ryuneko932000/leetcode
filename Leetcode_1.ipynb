# %% [markdown]
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order

# %%
class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/sebastianpatrickmacias/Documents/git_workspace/leetcode/Leetcode_1.ipynb Cell 2' in <cell line: 9>()
#       <a href='vscode-notebook-cell:/home/sebastianpatrickmacias/Documents/git_workspace/leetcode/Leetcode_1.ipynb#ch0000001?line=6'>7</a> list = [2,7,11,15],
#       <a href='vscode-notebook-cell:/home/sebastianpatrickmacias/Documents/git_workspace/leetcode/Leetcode_1.ipynb#ch0000001?line=7'>8</a> myT = 9
# ----> <a href='vscode-notebook-cell:/home/sebastianpatrickmacias/Documents/git_workspace/leetcode/Leetcode_1.ipynb#ch0000001?line=8'>9</a> twoSum(list, myT)
#
# /home/sebastianpatrickmacias/Documents/git_workspace/leetcode/Leetcode_1.ipynb Cell 2' in twoSum(nums, target)
#       <a href='vscode-notebook-cell:/home/sebastianpatrickmacias/Documents/git_workspace/leetcode/Leetcode_1.ipynb#ch0000001?line=0'>1</a> def twoSum(nums, target):
#       <a href='vscode-notebook-cell:/home/sebastianpatrickmacias/Documents/git_workspace/leetcode/Leetcode_1.ipynb#ch0000001?line=1'>2</a>     for i in nums:
# ----> <a href='vscode-notebook-cell:/home/sebastianpatrickmacias/Documents/git_workspace/leetcode/Leetcode_1.ipynb#ch0000001?line=2'>3</a>          if i + i+1 == target:
#       <a href='vscode-notebook-cell:/home/sebastianpatrickmacias/Documents/git_workspace/leetcode/Leetcode_1.ipynb#ch0000001?line=3'>4</a>             print(i, i+1)
#
# TypeError: can only concatenate list (not "int") to list
